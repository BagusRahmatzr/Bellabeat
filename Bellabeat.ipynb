# %% [markdown]
# ## Latar Belakang
#
# Sebagai Seorang Analisis data Junior yang bekerja di tim analisis pemasaran Bellabeat, yaitu produsen produk kesehatan wanita berteknologi tinggi. saya ditugaskan untuk diminta untuk fokus pada salah satu produk Bellabeat dan menganalisis data perangkat pintar untuk mendapatkan wawasan tentang bagaimana konsumen menggunakan perangkat pintar mereka.
#
# Urška Sršen, salah satu pendiri dan Chief Creative Officer Bellabeat, percaya bahwa menganalisis data kebugaran dari perangkat pintar dapat membantu membuka peluang pertumbuhan baru bagi perusahaan. Sršen tahu bahwa analisis data konsumen Bellabeat yang tersedia akan mengungkapkan lebih banyak peluang untuk pertumbuhan. Ia meminta tim analitik pemasaran untuk fokus pada produk Bellabeat dan menganalisis data penggunaan perangkat pintar untuk mendapatkan wawasan tentang bagaimana pelanggan menggunakan perangkat pintar mereka. Kemudian, dengan menggunakan informasi ini, ia menginginkan rekomendasi tingkat tinggi tentang bagaimana tren ini dapat membantu penyusunan strategi pemasaran Bellabeat.

# %% [markdown]
# ## Lingkup Kerja
#
# Proses analisis data
# 1. Bertanya
#   *   membuat dokumen lingkup kerja
#   *   mendefinisikan masalah, membuat pertanyaan yang jelas tentang masalah yang diberikan dan membuat batasan masalah yang akan diselesaikan
#   *   mengkonfirmasi tujuan proyek dan pengukuran untuk keuntungan bisnis dengan melakukan diskusi dan konfirmasi kepada stakeholder.
#
# 2. Mempersiapkan
#   *   mengumpulkan dan menyimpan data yang akan digunakan untuk proses analisis
#   *   mengorganisasikan data
#   *   melakukan pengecekan data apakah ROCCC (*Reliability, Origins, Comprehensiveness, Current relevance, and Credibility*).
#   *   menangani perizinan, privasi, keamanan, dan aksebilitas.
#   *   memverifikasi integritas data
#   *   melakukan pengecekan apakah data yang ada dapat menjawab pertanyaan yang dibutuhkan
#   *   melakukan pemfilteran dan penyortiran data.
#
# 3. Proses
#   *   menentukan tools yang akan digunakan
#   *   memastikan bahwa data sudah terintegritas ( mengecek apakah data usang, duplikat, tidak lengkap, tidak konsisten dan tidak akurat)
#   *   membersihkan data
#
# 4. Analisis
#   * mengatur dan memformat data
#   * Mengidentifikasi hubungan dan tren yang terdapat dalam data
#   * membuat kesimpulan atau ringkasan dari analisis
#
# 5. Membagikan
#   * membuat laporan yang menarik dengan memvisualisasikan data agar lebih mudah dipahami dan mempersentasikannya sehingga dapat menjawab permasalahan bisnis
# 6. Bertindak
#    * memberikan beberapa rekomendasi kepada tim pemasaranm berdasarkan analisis yang telah dilakukan untuk kemajuan bisnis

# %% [markdown]
# # **Fase Bertanya**
# ## Latar Belakang bisnis
# 1. Bellabeat, sebuah perusahaan teknologi tinggi yang memproduksi produk pintar yang berfokus pada kesehatan
# 2. Mengumpulkan data tentang aktivitas, tidur, stres, dan kesehatan reproduksi telah memungkinkan Bellabeat untuk memberdayakan wanita dengan pengetahuan tentang kesehatan dan kebiasaan mereka sendiri 3. Perusahaan telah berinvestasi di media periklanan tradisional, seperti radio, papan reklame luar rumah, media cetak, dan televisi, tetapi berfokus pada pemasaran digital secara ekstensif.
# 4. Produk  :
#    * Aplikasi Bellabeat yaitu Aplikasi Bellabeat menyediakan data kesehatan yang terkait dengan aktivitas, tidur, stres, siklus menstruasi, dan kebiasaan pengguna
#    * Leaf yaitu placak klasik bellabeat yang dapat di gunakan sebagai kalung, gelang, dan klip
#    * jam tangan kebugaran yang dapat membantu melacak aktivitas pengguna seperti tidur dan stress
#    *spring yaitu botol minum yang dapat melacak asupan air harian menggunakan teknologi pintar
#    *Keanggotaan Bellabeat berbasis langganan yang memberikan akses 24/7 kepanduan yang sepenuhnya di personalisasi

# %% [markdown]
# ## Diskusi Bersama Stakeholder
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Permasalahan
# Urška Sršen, salah satu pendiri dan Chief Creative Officer Bellabeat, percaya bahwa menganalisis data kebugaran dari perangkat pintar dapat membantu membuka peluang pertumbuhan baru bagi perusahaan dan membantu memandu strategi pemasaran perusahaan jika hasil dari stategi pemasaran berhasil di implementasikan maka dapat membuat perusahaan menjadi lebih berkembang di masa depan dan memperoleh lebih banyak keuntungan.

# %% [markdown]
# # Fase Persiapan
# ## Lingkup Pemerosesan
# 1. mengumpulkan dan menyimpan data yang akan digunakan untuk proses analisis
# 2. mengorganisasikan data
# 3. melakukan pengecekan data apakah ROCCC (Reliability, Origins, Comprehensiveness, Current relevance, and Credibility).
# 4. menangani perizinan, privasi, keamanan, dan aksebilitas.
# 5. memverifikasi integritas data
# 6. melakukan pengecekan apakah data yang ada dapat menjawab pertanyaan yang dibutuhkan
# 7. melakukan pemfilteran dan penyortiran data.
#
# # Sumber Data dan organisasi
# Data yang digunakan dapat dilihat [disini](https://www.kaggle.com/datasets/arashnic/fitbit) Data tersediah melalui [Mobius](https://www.kaggle.com/arashnichttps://) berikut.
# Catatan: Dataset tersebut memiliki nama yang berbeda karena Bellabeat adalah perusahaan fiksi. Untuk tujuan studi kasus ini

# %% [markdown]
# #Pengecekan ROCCC
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Privasi, keamanan, dan aksebilitas.
# 1. Privasi : data terbebas dari informasi pribadi
# 2. Keamanan : Data disimpan didalam repository cloud yang telah menyediakan sistem keamanan yang dapat dipercaya.
# 3. Aksebilitas :  data dapat diakses oleh publik
#
# # Integritas Data
# Nama untuk kolom tanggal berbeda untuk setiap tabel serta format  tanggal harus di perbaiki,  jumlah kolom konsisten, tipe data pada setiap kolom konsisten, ada beberapa data duplikat yang akan dihapus saat pembersihan data.
#
# # Pengecekan apakah data yang ada dapat menjawab pertanyaan yang dibutuhkan
# Integritas Data konsisten dan akurat sehingga dalam melakukan pembersihan, pemrosesan dan analisis tidak ada masalah
#
# # Pemfilteran dan penyortiran data.
# Tidak ada masalah dalam tahap verifikasi awal dan akan ditentukan selama proses pembersihan.

# %% [markdown]
# # Fase Pemrosesan

# %%
library(tidyverse)
library(lubridate)
library(ggplot2)
library(dplyr)
library(anytime)
library(skimr)
library(janitor)
library(here)
library(ggrepel)

dailyActivity <- read.csv('D:\\Data Analis\\Bellabeat\\dailyActivity.csv')
dailyCalories <- read.csv('D:\\Data Analis\\Bellabeat\\dailyCalories.csv')
dailyIntensities <- read.csv('D:\\Data Analis\\Bellabeat\\dailyIntensities.csv')
dailySteps <- read.csv('D:\\Data Analis\\Bellabeat\\dailySteps.csv')
sleepDay <- read.csv('D:\\Data Analis\\Bellabeat\\sleepDay.csv')
weight <- read.csv('D:\\Data Analis\\Bellabeat\\weight.csv')

colnames(dailyActivity)
colnames(dailyCalories)
colnames(dailyIntensities)
colnames(dailySteps)
colnames(sleepDay)
colnames(weight)


head(dailyActivity)
head(dailyCalories)
head(dailyIntensities)
head(dailySteps)
head(sleepDay)
head(weight)

glimpse(dailyActivity)
glimpse(dailyCalories)
glimpse(dailyIntensities)
glimpse(dailySteps)
glimpse(sleepDay)
glimpse(weight)

# Pembersihan data

# melihat jumlah pengguna
n_unique(dailyActivity$Id)
n_unique(dailyCalories$Id)
n_unique(dailyIntensities$Id)
n_unique(dailySteps$Id)
n_unique(sleepDay$Id)
n_unique(weight$Id)

# melihat banyak duplikat
sum(duplicated(dailyActivity)) # 0 duplikat
sum(duplicated(dailyCalories)) # 0 duplikat
sum(duplicated(dailyIntensities)) # 0 duplikat
sum(duplicated(dailySteps)) # 0 duplikat
sum(duplicated(sleepDay))# 3 duplikat
sum(duplicated(weight)) # 0 duplikat

#hapus duplikat pada tabel sleep
sleepDay <- sleepDay[!duplicated(sleepDay), ]

# cek kembali data duplikat
sum(duplicated(dailyActivity))
sum(duplicated(dailyCalories)) 
sum(duplicated(dailyIntensities))
sum(duplicated(dailySteps)) 
sum(duplicated(sleepDay))
sum(duplicated(weight))

#menghapus duplikat dan Null(N/A)
dailyActivity <- dailyActivity %>%
  distinct() %>%
  drop_na()

dailyCalories <- dailyCalories %>%
  distinct() %>%
  drop_na()

dailyIntensities <-dailyIntensities %>%
  distinct() %>%
  drop_na()

dailySteps <- dailySteps %>%
  distinct() %>%
  drop_na()

sleepDay <- sleepDay %>%
  distinct() %>%
  drop_na()

weight <- weight %>%
  distinct() %>%
  drop_na()

# Memperbaiki format penanggalan
dailyActivity <- dailyActivity %>%
  rename(date = ActivityDate) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))

dailyCalories <- dailyCalories %>%
  rename(date = ActivityDay) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))

dailyIntensities <-dailyIntensities %>%
  rename(date = ActivityDay) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))

dailySteps <-dailySteps %>%
  rename(date = ActivityDay) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))

sleepDay <-sleepDay %>%
  rename(date = SleepDay) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))

weight <-weight %>%
  rename(date = Date) %>%
  mutate(date = as.Date(date, format = "%m/%d/%Y"))
  
head(dailyActivity)
head(dailyCalories)
head(dailyIntensities)
head(dailySteps)
head(sleepDay)
head(weight)

# %% [markdown]
# # Fase Analisis

# %%
summary(dailyActivity)
summary(sleepDay)
summary(dailySteps)
summary(dailyCalories)
summary(weight)

dailyActvity_and_Sleep <- merge(dailyActivity, sleepDay, by=c("Id","date"))
glimpse(dailyActvity_and_Sleep)

ggplot(data = dailyActivity, aes(x=TotalSteps, y=Calories, color=date)) + 
  geom_point() + geom_smooth(method = 'loess', formula= 'y ~ x') + 
  labs(title = "Total Steps vs. Calories", x="Total Steps")

ggplot(data = dailyActivity, aes(x=TotalDistance, y=Calories, color=date)) + 
  geom_point() + geom_smooth(method = 'loess', formula= 'y ~ x')+
  labs(title = "Total Distance vs. Calories", x="Total Distance")

ggplot(data = dailyActivity, aes(x=SedentaryMinutes, y=Calories, color=date)) + 
  geom_point() + geom_smooth(method = 'loess', formula= 'y ~ x')+
  labs(title = "Sedentary Minutes vs. Calories", x="Sedentary Minutes")

ggplot(data = sleepDay, aes(x=TotalTimeInBed, y=TotalMinutesAsleep, color=date)) + 
  geom_point() + geom_smooth(method = 'loess', formula= 'y ~ x')+
  labs(title = "Total Minutes A sleep vs. Total Time In Bed", x="Total Time In Bed", y="Total Minutes A sleep")

ggplot(data = dailyActvity_and_Sleep, aes(x=TotalMinutesAsleep, y=TotalSteps, color=Calories)) + 
  geom_point() +
  labs(title = "Total Minutes A sleep vs. TotalSteps", x="Total Minutes A sleep", y="Total Steps") +
  geom_smooth(formula = y ~ x, method=lm, mapping = aes(y = TotalSteps, x = TotalMinutesAsleep), color = "blue") +
  geom_vline(xintercept=420,linetype="dashed",size=.5, color = "red") +
  geom_vline(xintercept=540,linetype="dashed",size=.5, color = "red")

ggplot(data = dailyActvity_and_Sleep, aes(x=TotalMinutesAsleep, y=Calories)) + 
  geom_point() +
  labs(title = "Total Minutes A sleep vs. Calories", x="Total Minutes Asleep") +
  geom_smooth(formula = y ~ x, method=lm, mapping = aes(y = Calories, x = TotalMinutesAsleep), color = "blue") +
  geom_vline(xintercept=420,linetype="dashed",size=.5, color = "red") +
  geom_vline(xintercept=540,linetype="dashed",size=.5, color = "red")

ggplot(data = dailyActvity_and_Sleep, aes(x=TotalMinutesAsleep, y=SedentaryMinutes, color=Calories)) + 
  geom_point() +
  labs(title = "Total Minutes A sleep vs. Sedentary Minutes", y="Sedentary Minutes", x="Total Minutes Asleep") +
  geom_smooth(formula = y ~ x, method=lm, mapping = aes(y = SedentaryMinutes, x = TotalMinutesAsleep), color = "blue") +
  geom_vline(xintercept=420,linetype="dashed",size=.5, color = "red") +
  geom_vline(xintercept=540,linetype="dashed",size=.5, color = "red")

# %% [markdown]
# #Visualisasi Hasil Analisis

# %% [markdown]
#  ![Total step vs Calories.jpg](data:image/jpeg;base64,...)
#
# Dari hasil visualisasi dilihat bahwa kebanyakan total langkah yang dilakukann pengguna rata rata berkisar dari 0 – 15000, dengan kalori yang dibakar sebesar 1000-3500. Dapat disimpulkan juga semakin banyak total langkah yang dilakukan pengguna maka semakin banyak kalori yang dibakar,
#
# ![Total Distance vs Calories.jpg](data:image/jpeg;base64,...)
#
# Hubungan antara kalori dan total jarak pengguna menunjukan hubungan positif dimana semakin jauh jarak perjalanan maka semakin tinggi kalori yang dibakar
#
# ![Sedentary Minut vs Calories.jpg](data:image/jpeg;base64,...)
#
# hubungan antara waktu istirahat dan kalori yang dibakar menunjukan hubungan yang negative. Dimana semakin lama waktu yang digunakan untuk beristirahat maka semakin menurun kalori yang diabakar,  maka sebaiknya waktu istirahat diataur agar meminimalisir waktu istirahat yang terlalu lama
#
# ![Total Minutes A sleep vs TotalSteps .jpg](data:image/jpeg;base64,...)
#
# Hubungan antara total langkah dan total menit tidur menunjukan hubungan yang negative dimana semakin tinggi total langkah maka semakin menurun waktu tidur pengguna
#
#
# ![Total Minutes A sleep vs Sedentary Minutes.jpg](data:image/jpeg;base64,...)
# Hubungan antara waktu istirahat dan waktu tidur menunjukan hubungan yeng negative dimana semakin tinggi waktu istirahat maka semakin menurun waktu tidur pengguna
#
# ![Total Minutes A sleep vs Calories.jpg](data:image/jpeg;base64,...)
#
# Hubungan antara total waktu tidur dan kalori tidak menunjukan hubungan negative ataupun positif sehingga keduanya tidak meiliki kolerasi.
#
# ![TotalMinutesInBed.jpg](data:image/jpeg;base64,...)
#
# Hubungan antara total waktu tidur dan total saat ditempat tidur menunjukan ubungan yang positif dimana semakin lama kita di tempat tidur  maka semakin tinggi waktu kita tidur

# %% [markdown]
# ##Fase Bertindak
#
# berdasarkan analisis yang telah dilakukan didapatkan fakta bahwa :
# 1.	BMI rata rata pengguna bellabeat  sebesar 25,05 dimana menurut penelitian yang dilakukan John S. Garrow BMI ditatas 25 termasuk kedalam obesitas Grade 1
# 2.	Rata rata tidur perhari yang di lakukan pengguna bellabeat yaitu 419,2 menit  perhari atau  kurang dari  8 jam  serta memerlukan waktu 39,3 menit untuk tertidur sehingga dapat diartikan bahwa banyak pengguna bellabeat yang memiliki kualitas tidur tidak baik.
# 3.	Rata rata langka kaki pengguna bellabeat perhari sebesar 7638 dimana angka tersebut masih dibawah langka kaki yang di rekomendasikan yaitu 10.000 lahngkah perhari
# 4.	Rata rata istirahat yang dilakukan pengguna bellabeat sebesar 991,1 atau 16 jam 52 menit dimana angka tersebut sangat tinggi
#
# ## Rekomendasi
# -	Diperlukan fitur fitur tambahan yang dapat digunakan sebagai alaram atau penanda agar langkah perhari yang direkomendasikan terpenuhi
# -	Diperlukan fitur yang dapat  mengatur pola tidur dengan aktivitas yang dilakukan agar pola tidur ideal terpenuhi dan mengurangi gangguan tidur
# -	Membuat fitur pengaturan istirahat dengan menghitung jumlah langkah yang dilakukan per hari
# -	Dari hasil analisis didapatkan data bahwa waktu istirahat pengguna mencapai 991, 1 menit atau 16 jam 52 menit, untuk dapat meningkatkan aktivitas dan menurunkan waktu istirahat dapat ditambahkan fitur fitur yang membantu pengguna untuk mengurangi waktu istirahat mereka seperti video pendek ataupun pengingat untuk melakukan olahraga dan peregangan.
